# %% [markdown]
# <a href="https://colab.research.google.com/github/marianmarengo2-svg/correlaciones_factor_friccion_intercambiadores/blob/main/Correlaciones_para_factor_de_friccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mapa General de Correlaciones de Fricción ($f$)
#
# El factor de fricción de Darcy-Weisbach es la base para calcular la caída de presión ($\Delta P$).
#
# La elección de la correlación depende de dos factores: el Régimen de Flujo y la Ubicación (Tubos o Carcasa).

# %% [markdown]
# # Investigación exhaustiva - Factor de fricción intercambiadores de calor

# %% [markdown]
# ## Introducción y nomenclatura

# %% [markdown]
# ## Factor de fricción en tubos (Flujo interno)

# %% [markdown]
# ## Factor de fricción en carcasa (Lado coraza)

# %% [markdown]
# ### Ecuación de Kern para la Carcasa
# La caída de presión se define como:
# $$\Delta P_s = \frac{f_s \cdot G_s^2 \cdot D_i \cdot (N+1)}{2 \cdot \rho \cdot D_e}$$

# %% [markdown]
# ## Calculadora interactiva (phyton)
